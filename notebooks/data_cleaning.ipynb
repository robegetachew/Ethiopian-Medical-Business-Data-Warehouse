# %% [markdown]
# # **Data Cleaning sample and Working with Local Database connection**

# %%
# Import modules
import sys
import os
import pandas as pd

# %%
# Add the 'scripts' directory to the Python path for module imports
sys.path.append(os.path.abspath(os.path.join('..', 'scripts')))

# %%
# Now import the modules
from data_cleaning import load_csv, clean_dataframe, save_cleaned_data

# %% [markdown]
# ### **Load and Inspect Raw Data**

# %%
df = load_csv("../data/messages/scraped_messages.csv")

# Show first few rows
df.head(10)
# Out:
#   channel_name     channel_title                 date  \
# 0    DoctorsET  Doctors Ethiopia  2023-12-18 17:04:02
# 1    DoctorsET  Doctors Ethiopia  2023-11-03 16:14:39
# 2    DoctorsET  Doctors Ethiopia  2023-10-02 16:37:39
# 3    DoctorsET  Doctors Ethiopia  2023-09-16 07:54:32
# 4    DoctorsET  Doctors Ethiopia  2023-09-01 16:16:15
# 5    DoctorsET  Doctors Ethiopia  2023-08-29 17:20:05
# 6    DoctorsET  Doctors Ethiopia  2022-08-02 17:42:08
# 7    DoctorsET  Doctors Ethiopia  2022-06-12 17:15:47
# 8    DoctorsET  Doctors Ethiopia  2022-05-31 17:51:13
# 9    DoctorsET  Doctors Ethiopia  2022-05-20 18:04:53
#
#                                                 text
# 0  https://youtu.be/5DBoEm-8kmA?si=LDLuEecNfULJVD...
# 1  ዶክተርስ ኢትዮጵያ በ አዲስ አቀራረብ በ ቴሌቪዥን ፕሮግራሙን ለመጀመር ከ...
# 2  ሞት በስኳር \n\nለልጆቻችን የምናሲዘው ምሳቃ ሳናቀው እድሚያቸውን ይቀን...
# 3  ከ HIV የተፈወሰ ሰው አጋጥሟችሁ ያቃል ? ፈውስ እና ህክምና ?\n\nሙ...
# 4  በቅርብ ጊዜ በሃገራችን ላይ እየተስተዋለ ያለ የተመሳሳይ ፆታ ( Homos...
# 5  👇👇👇👇👇👇 https://youtu.be/-AR1KO2DbFw?si=47cXLZt...
# 6  ክረምቱን ስፖርት መስራት አስበው ጂም ለመግባት ካልቻሉ ባሉበት ቦታ ሆነው...
# 7  ስፖርት የመስራት ሱስ ይኖር ይሆን?\n\nበአሁኑ ወቅት ብዙ የስፖርት መስ...
# 8  ድንገተኛ አደጋ / የአጥንት ስብራት\n\nአያርገውና ድንገተኛ የሆነ አደጋ...
# 9  ከትንሽ ግዚያት በፊት ስፖርት መስራት እንደ ቅንጦት ይታይ ነበር አሁን ላ...

# %% [markdown]
# ### **Clean and Standardize Data**

# %%
df_cleaned = clean_dataframe(df)

# Display cleaned dataset
df_cleaned.head(50)
# Out:
#    channel_name     channel_title            text_date  \
# 0     DoctorsET  Doctors Ethiopia  2023-12-18 17:04:02
# 1     DoctorsET  Doctors Ethiopia  2023-11-03 16:14:39
# 2     DoctorsET  Doctors Ethiopia  2023-10-02 16:37:39
# 3     DoctorsET  Doctors Ethiopia  2023-09-16 07:54:32
# 4     DoctorsET  Doctors Ethiopia  2023-09-01 16:16:15
# 5     DoctorsET  Doctors Ethiopia  2023-08-29 17:20:05
# 49    DoctorsET  Doctors Ethiopia  2022-04-01 17:02:54
#
#                                               message      emoji_used
# 0   በቀን አንዴ ብቻ የሚባለው የቢዝነስ አማካሪ  በ 10,000 ብር ብቻ የተ...            👈👈👇👇
# 1   ዶክተርስ ኢትዮጵያ በ አዲስ አቀራረብ በ ቴሌቪዥን ፕሮግራሙን ለመጀመር ከ...               👇
# 2   ሞት በስኳር  ለልጆቻችን የምናሲዘው ምሳቃ ሳናቀው እድሚያቸውን ይቀንሰው ...        No emoji
# 3   ከ HIV የተፈወሰ ሰው አጋጥሟችሁ ያቃል ? ፈውስ እና ህክምና ? ሙሉ ቪ...            👇👇👇👇
# 4   በቅርብ ጊዜ በሃገራችን ላይ እየተስተዋለ ያለ የተመሳሳይ ፆታ ( Homos...        No emoji
# 5   ** ዶክተርስ ኢትዮጽያ በአዲስ ፕሮገራም ጀመረ** ማረጥ  (**ሜኖፖዝ )...          👇👇👇👇👇👇
# 6   ክረምቱን ስፖርት መስራት አስበው ጂም ለመግባት ካልቻሉ ባሉበት ቦታ ሆነው...           👇👇👇👇👇
# 7   ስፖርት የመስራት ሱስ ይኖር ይሆን? በአሁኑ ወቅት ብዙ የስፖርት መስሪያ ...          👇👇👇👇👇👇
# 8   ድንገተኛ አደጋ / የአጥንት ስብራት አያርገውና ድንገተኛ የሆነ አደጋ ቢደ...         👇👇👇👇👇👇👇
# 9   ከትንሽ ግዚያት በፊት ስፖርት መስራት እንደ ቅንጦት ይታይ ነበር አሁን ላ...          👇👇👇👇👇👇
# 10  **ልጆች ላላችሁ / አባት እናት ወይንም እህት ወንድም / በቅርቡ ልጅ ለ...            👇👇👇👇
# 11  **በብዙ ማህበራዊ ሚዲያዎች በ ከፋተኛ ሁኔታ እየተሸጠ ያለው  ፕሮቲን- ...  👇👇👇👇👇👇👇👇👇👇👇👇👇👇
# 12                                          [No Text]        No emoji
# 13                                          [No Text]        No emoji
# 14                                          [No Text]        No emoji
# 15  ዛሬ ምሽት 3:30 በ ፋና ቴሌቪዥን      ስለ ፕሮቲን : ክሬቲን ፓውደ...        No emoji
# 16  ከሳምንት በፊት በለቀቅነው ቦርጭን በህክምና እንዴት ማጥፋት ይቻላል በሚለ...        No emoji
# 17                                          [No Text]        No emoji
# 18                                          [No Text]        No emoji
# 19                                          [No Text]        No emoji
# 20                                          [No Text]        No emoji
# 21                                          [No Text]        No emoji
# 22  ሃያት ሆስፒታል ሜዲካል ኮሌጅ   ህክምና ለማግኘት አስበዋል ? የት መሄድ...        No emoji
# 23  ፈጣን የ ቦርጭ ማጥፊያ ዘዴ ወንድም ሴትም ላይ ቦርጭ ሊኖር ይችላል ብዙ ...          👇👇👇👇👇👇
# 24  የዶክተርስ ኢትዮጵያ እንግዳ  ትንሳይ ብርሃኑ  ISSA certified p...        No emoji
# 25                                          [No Text]        No emoji
# 26                                          [No Text]        No emoji
# 27                                          [No Text]        No emoji
# 28                                          [No Text]        No emoji
# 29                                          [No Text]        No emoji
# 30  ዛሬ ምሽት 3:30 በ ፋና ቴሌቪዥን             ልዮ ፕሮግራም  *...        No emoji
# 31  ከ ፆም በኋላ ፈፅሞ ማድረግ የሌለብን የገሮች ምንድን ናቸው? አመጋገባችን...          👇👇👇👇👇👇
# 32                                          [No Text]        No emoji
# 33                                          [No Text]        No emoji
# 34  ዛሬ ምሽት 3:30 በ ፋና ቴሌቪዥን    **ዶክተርስ ገበታ ፕሮግራም **...        No emoji
# 35  Ethiopian Medical Association's 58th Medical C...        No emoji
# 36  **ስለ ወንድ ዘር ማወቅ ያለቦት ዋና ዋና ነገሮች  ቁመት ይጨምራል ? በ...     👇👇👇👇👇👇👇👇👇👇👇
# 37                                          [No Text]        No emoji
# 38                                          [No Text]        No emoji
# 39                                          [No Text]        No emoji
# 40  ዛሬ ምሽት 3:30 በ ፋና ቴሌቪዥን ዶክተርስ ኢትዮጵያ            ...        No emoji
# 41                                          [No Text]        No emoji
# 42                                          [No Text]        No emoji
# 43                                          [No Text]        No emoji
# 44  ውድ የዶክተርስ ኢትዮጵያ ቤተሰቦች   ሃያት ሆስፒታል በአዲስ አስተዳደር ...        No emoji
# 45  ሽንቶን ሲሸኑ ምን አይነት ቀለም አለው ? ሽንት ላይ ደም አለ ሲባል ምን...         👇👇👇👇👇👇👇
# 46  ላለፉት 21 አመታት በመምህርነት በተለያዩ ትምህርት ቤቶች ውስጥ አስተምሬ...        No emoji
# 47                                          [No Text]        No emoji
# 48                                          [No Text]        No emoji
# 49                                          [No Text]        No emoji

# %%
# Check for missing values in the cleaned DataFrame
missing_values = df_cleaned.isnull().sum()
missing_values[missing_values > 0]
# Out:
# Series([], dtype: int64)

# %%
# Get the dimensions of the DataFrame: (number of rows, number of columns)
df_cleaned.shape
# Out:
# (3828, 5)

# %% [markdown]
# The output (3828, 5) indicates that the DataFrame contains 3828 rows and 5 columns.

# %%
# Get the total number of elements in the DataFrame (rows * columns)
df_cleaned.size
# Out:
# 19140

# %% [markdown]
# ### **Save the Cleaned Data**

# %%
# Save cleaned data to CSV
save_cleaned_data(df_cleaned, "../data/processed/cleaned_telegram_data.csv")
# Out:
# ✅ Cleaned data saved successfully to '../data/processed/cleaned_telegram_data.csv'.

# %% [markdown]
# # **Connect to Database**

# %%
from database_setup import get_db_connection, create_table, insert_data
engine = get_db_connection()

# %% [markdown]
# ###  **Create Table in PostgreSQL**

# %%
create_table(engine)

# %% [markdown]
# ###  **Insert Data into Database**

# %%
# Load the cleaned CSV into a DataFrame
cleaned_df = pd.read_csv("../data/cleaned_telegram_data.csv")

# %%
# Ensure the 'message_date' column is in datetime format (to prevent NaT issues)
cleaned_df["text_date"] = pd.to_datetime(cleaned_df["text_date"], errors="coerce")

# Check if there are any missing values before inserting
missing_values = cleaned_df.isnull().sum()
print("Missing Values Before Insert:", missing_values)
# Out:
# Missing Values Before Insert: channel_name     0
# channel_title    0
# text_date        0
# message          3
# emoji_used       0
# dtype: int64
